# %%
import pandas as pd

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
schema_df=pd.read_csv("survey_results_schema.csv")

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
schema_df.shape
# Out:
# (79, 6)

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
dict_df=pd.DataFrame(people)

# %%
dict_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
dict_df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
dict_df[["email","last"]]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe
# 2        JohnDoe@email.com      Doe

# %%
dict_df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
dict_df.iloc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
dict_df.iloc[[0,1],2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
dict_df.loc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
dict_df.loc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
dict_df.loc[[0,1],["email"]]
# Out:
#                      email
# 0  CoreyMSchafer@gmail.com
# 1        JaneDoe@email.com

# %%
dict_df.loc[[0,1],["email","last"]]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df["RemoteWork"]
# Out:
# 0                                         NaN
# 1                                Fully remote
# 2        Hybrid (some remote, some in-person)
# 3                                Fully remote
# 4        Hybrid (some remote, some in-person)
#                          ...
# 73263                            Fully remote
# 73264                          Full in-person
# 73265    Hybrid (some remote, some in-person)
# 73266    Hybrid (some remote, some in-person)
# 73267                            Fully remote
# Name: RemoteWork, Length: 73268, dtype: object

# %%
df["RemoteWork"].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64

# %%
df.loc[[0,1,2,3,4,5,6,7],"RemoteWork"]
# Out:
# 0                                     NaN
# 1                            Fully remote
# 2    Hybrid (some remote, some in-person)
# 3                            Fully remote
# 4    Hybrid (some remote, some in-person)
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# Name: RemoteWork, dtype: object

# %%
df.loc[0:7,"RemoteWork"]
# Out:
# 0                                     NaN
# 1                            Fully remote
# 2    Hybrid (some remote, some in-person)
# 3                            Fully remote
# 4    Hybrid (some remote, some in-person)
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# Name: RemoteWork, dtype: object

# %%
df.loc[0:7,"RemoteWork":"DevType"]
# Out:
#                              RemoteWork  \
# 0                                   NaN
# 1                          Fully remote
# 2  Hybrid (some remote, some in-person)
# 3                          Fully remote
# 4  Hybrid (some remote, some in-person)
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
#
#                                              EdLevel  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
dict_df.set_index("email",inplace=True)

# %%
dict_df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
dict_df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
dict_df.loc["CoreyMSchafer@gmail.com"]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
dict_df.reset_index(inplace=True)

# %%
schema_df.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %% [markdown]
# ### Filtering the Data

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
high_salary=(df["CompTotal"]>70000)

# %%
high_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73263    False
# 73264     True
# 73265    False
# 73266    False
# 73267    False
# Name: CompTotal, Length: 73268, dtype: bool

# %%
df.loc[high_salary,"WebframeWantToWorkWith"]
# Out:
# 11       ASP.NET Core ;Node.js;Nuxt.js;React.js;Vue.js
# 14                      Django;FastAPI;React.js;Vue.js
# 17                                                 NaN
# 22                                       ASP.NET Core
# 25                                     Express;Node.js
#                              ...
# 73246                                 Node.js;React.js
# 73253                                              NaN
# 73254                                              NaN
# 73258                                              NaN
# 73264                                 FastAPI;React.js
# Name: WebframeWantToWorkWith, Length: 20183, dtype: object

# %%
countries=["India","United States"]

# %%
country_filt=df["Country"].isin(countries)

# %%
country_filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73263    False
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# Name: Country, Length: 73268, dtype: bool

# %%
df.loc[country_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 65             66                     I am a developer by profession
# 140           141                     I am a developer by profession
# 151           152                     I am a developer by profession
# ...           ...                                                ...
# 73184       73185                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 6                      Student, part-time
# 7      Not employed, but looking for work
# ...

# %%
df["LanguageHaveWorkedWith"]
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
languages_filt=df["LanguageHaveWorkedWith"].str.contains("Python",na=False)

# %%
languages_filt
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266    False
# 73267    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
df.loc[languages_filt,"LanguageHaveWorkedWith"]
# Out:
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 11       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 14             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 16                                    C#;Java;PHP;Python;R
#                                ...
# 73257                                         C;Python;SQL
# 73261    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %% [markdown]
# ### Adding and deleting rows operation in pandas dataframe

# %%
people2 = {
    "first": ["Steve", 'Tony', 'Peter'], 
    "last": ["Rogers", 'Stark', 'Parker'], 
    "email": ["capamerica@gmail.com", 'ironman@email.com', 'spiderman@email.com']
}

# %%
dict_df2=pd.DataFrame(people2)

# %%
dict_df2
# Out:
#    first    last                 email
# 0  Steve  Rogers  capamerica@gmail.com
# 1   Tony   Stark     ironman@email.com
# 2  Peter  Parker   spiderman@email.com

# %%
dict_df=dict_df.append(dict_df2,ignore_index=True,sort=False)

# %%
dict_df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe
# 3     capamerica@gmail.com  Steve   Rogers
# 4        ironman@email.com   Tony    Stark
# 5      spiderman@email.com  Peter   Parker

# %% [markdown]
# ### Sorting

# %%
dict_df.sort_values(by="last")
# Out:
#                      email  first     last
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe
# 5      spiderman@email.com  Peter   Parker
# 3     capamerica@gmail.com  Steve   Rogers
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 4        ironman@email.com   Tony    Stark

# %%
dict_df.sort_index()
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe
# 3     capamerica@gmail.com  Steve   Rogers
# 4        ironman@email.com   Tony    Stark
# 5      spiderman@email.com  Peter   Parker

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df[["Country","CompTotal"]].head(50)
# Out:
#                                               Country  CompTotal
# 0                                                 NaN        NaN
# 1                                              Canada        NaN
# 2   United Kingdom of Great Britain and Northern I...    32000.0
# 3                                              Israel    60000.0
# 4                            United States of America        NaN
# 5                                             Germany        NaN
# 6                                               India        NaN
# 7                                               India        NaN
# 8                                         Netherlands    46000.0
# 9                                             Croatia        NaN
# 10  United Kingdom of Great Britain and Northern I...    48000.0
# 11                           United States of America   194400.0
# 12                           United States of America    65000.0
# ...

# %%
df.sort_values(by=["Country","CompTotal"],ascending=[True,False],inplace=True)

# %%
df
# Out:
#        ResponseId                      MainBranch  \
# 6891         6892  I am a developer by profession
# 38512       38513  I am a developer by profession
# 43639       43640  I am a developer by profession
# 43690       43691  I am a developer by profession
# 2448         2449  I am a developer by profession
# ...           ...                             ...
# 73109       73110                   None of these
# 73157       73158                   None of these
# 73201       73202                   None of these
# 73215       73216                   None of these
# 73243       73244                   None of these
#
#                                               Employment  \
# 6891                                 Employed, full-time
# 38512                                Employed, full-time
# 43639  Employed, full-time;Independent contractor, fr...
# 43690  Employed, full-time;Independent contractor, fr...
# 2448                                 Employed, full-time
# ...

# %%
df[["Country","CompTotal"]].head(50)
# Out:
#            Country   CompTotal
# 6891   Afghanistan  55000000.0
# 38512  Afghanistan   1200000.0
# 43639  Afghanistan    700000.0
# 43690  Afghanistan    100000.0
# 2448   Afghanistan     40000.0
# 6242   Afghanistan     40000.0
# 23223  Afghanistan     40000.0
# 49273  Afghanistan      6000.0
# 55665  Afghanistan       200.0
# 3886   Afghanistan         1.0
# 5464   Afghanistan         1.0
# 6776   Afghanistan         1.0
# 17469  Afghanistan         1.0
# 2737   Afghanistan         0.0
# 67666  Afghanistan         0.0
# 1959   Afghanistan         NaN
# 3641   Afghanistan         NaN
# 3775   Afghanistan         NaN
# 4502   Afghanistan         NaN
# 7944   Afghanistan         NaN
# 8890   Afghanistan         NaN
# 10233  Afghanistan         NaN
# 10910  Afghanistan         NaN
# 13851  Afghanistan         NaN
# 15607  Afghanistan         NaN
# 17038  Afghanistan         NaN
# 19201  Afghanistan         NaN
# 21765  Afghanistan         NaN
# 22876  Afghanistan         NaN
# ...

# %%
 df["CompTotal"].nlargest(10)
# Out:
# 35786    9.000000e+56
# 3068     1.000000e+52
# 70597    1.000000e+22
# 17567    1.000000e+15
# 19244    5.000000e+12
# 24640    1.500070e+12
# 31190    1.000000e+12
# 71603    9.363220e+09
# 34411    7.200000e+09
# 49874    6.438169e+09
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10,"CompTotal")
# Out:
#        ResponseId                                         MainBranch  \
# 35786       35787                     I am a developer by profession
# 3068         3069                     I am a developer by profession
# 70597       70598                     I am a developer by profession
# 17567       17568                     I am a developer by profession
# 19244       19245  I am not primarily a developer, but I write co...
# 24640       24641                     I am a developer by profession
# 31190       31191                     I am a developer by profession
# 71603       71604                     I am a developer by profession
# 34411       34412                     I am a developer by profession
# 49874       49875                     I am a developer by profession
#
#                                               Employment  \
# 35786            Employed, full-time;Employed, part-time
# 3068                                 Employed, full-time
# ...

# %% [markdown]
# ### Grouping and Aggregating the dataset

# %%
df["CompTotal"].head(10)
# Out:
# 6891     55000000.0
# 38512     1200000.0
# 43639      700000.0
# 43690      100000.0
# 2448        40000.0
# 6242        40000.0
# 23223       40000.0
# 49273        6000.0
# 55665         200.0
# 3886            1.0
# Name: CompTotal, dtype: float64

# %%
df["CompTotal"].median() #median salary of developers
# Out:
# 77500.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ResponseId                   36634.5
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
df["CompTotal"].count()
# Out:
# 38422

# %%
df["CodingActivities"].head(10)
# Out:
# 6891     Contribute to open-source projects;Freelance/c...
# 38512    Hobby;Contribute to open-source projects;Boots...
# 43639                       Hobby;Bootstrapping a business
# 43690    Hobby;Contribute to open-source projects;Boots...
# 2448     Hobby;Contribute to open-source projects;Schoo...
# 6242       Freelance/contract work;School or academic work
# 23223                              School or academic work
# 49273    Hobby;Contribute to open-source projects;Boots...
# 55665    Hobby;Contribute to open-source projects;Freel...
# 3886              Hobby;Contribute to open-source projects
# Name: CodingActivities, dtype: object

# %%
df["CodingActivities"].value_counts()
# Out:
# Hobby                                                                                                                                        18118
# I don’t code outside of work                                                                                                                  7311
# Hobby;Contribute to open-source projects                                                                                                      6549
# Hobby;Freelance/contract work                                                                                                                 3554
# Hobby;School or academic work                                                                                                                 3016
# Freelance/contract work                                                                                                                       2189
# ...

# %%
schema_df.head(5)
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
schema_df["qname"]
# Out:
# 0                       S0
# 1                 MetaInfo
# 2                       S1
# 3               MainBranch
# 4               Employment
# 5               RemoteWork
# 6         CodingActivities
# 7                       S2
# 8                  EdLevel
# 9                LearnCode
# 10         LearnCodeOnline
# 11    LearnCodeCoursesCert
# 12               YearsCode
# 13            YearsCodePro
# 14                 DevType
# 15                 OrgSize
# 16       PurchaseInfluence
# 17              BuyNewTool
# 18                 Country
# 19                Currency
# 20               CompTotal
# 21                CompFreq
# 22                      S3
# 23                Language
# 24                Database
# 25                Platform
# 26                Webframe
# 27                MiscTech
# 28               ToolsTech
# 29          NEWCollabTools
# 30                   OpSys
# 31    VersionControlSystem
# 32           VCInteraction
# 33               VCHosting
# ...

# %%
df["EdLevel"].value_counts(normalize=True) #Analyzing the education level
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.423020
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.216373
# Some college/university study without earning a degree                                0.130304
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.110436
# Associate degree (A.A., A.S., etc.)                                                   0.031242
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.030306
# Primary/elementary school                                                             0.025234
# Something else                                                                        0.017423
# Professional degree (JD, MD, etc.)                                                    0.015663
# Name: EdLevel, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
country_df=df.groupby(["Country"])

# %%
country_df.get_group("India").head(5)  #getting the responses from only India
# Out:
#        ResponseId                      MainBranch           Employment  \
# 64897       64898  I am a developer by profession  Employed, full-time
# 12131       12132  I am a developer by profession  Employed, full-time
# 25937       25938  I am a developer by profession  Employed, full-time
# 9795         9796  I am a developer by profession  Employed, full-time
# 57353       57354  I am a developer by profession  Employed, full-time
#
#                                  RemoteWork  \
# 64897                          Fully remote
# 12131  Hybrid (some remote, some in-person)
# 25937  Hybrid (some remote, some in-person)
# 9795   Hybrid (some remote, some in-person)
# 57353  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 64897                                              Hobby
# 12131                            School or academic work
# 25937  Hobby;Contribute to open-source projects;Boots...
# ...

# %%
India_filt=df["Country"]=="India"
df.loc[India_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 64897       64898                     I am a developer by profession
# 12131       12132                     I am a developer by profession
# 25937       25938                     I am a developer by profession
# 9795         9796                     I am a developer by profession
# 57353       57354                     I am a developer by profession
# ...           ...                                                ...
# 73133       73134  I am not primarily a developer, but I write co...
# 73178       73179                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
#
#                 Employment                            RemoteWork  \
# 64897  Employed, full-time                          Fully remote
# ...

# %%
df.loc[India_filt]["EdLevel"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          4121
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       1129
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     704
# Some college/university study without earning a degree                                 334
# Primary/elementary school                                                              158
# Something else                                                                          80
# Professional degree (JD, MD, etc.)                                                      46
# Other doctoral degree (Ph.D., Ed.D., etc.)                                              23
# Associate degree (A.A., A.S., etc.)                                                     21
# Name: EdLevel, dtype: int64

# %%
country_df["EdLevel"].value_counts()
# Out:
# Country      EdLevel
# Afghanistan  Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26
#              Primary/elementary school                                                              9
#              Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        8
#              Some college/university study without earning a degree                                 8
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     6
#                                                                                                    ..
# Zimbabwe     Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          12
#              Some college/university study without earning a degree                                11
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5
# ...

# %%
country_df["EdLevel"].value_counts().loc["India"]
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          4121
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       1129
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     704
# Some college/university study without earning a degree                                 334
# Primary/elementary school                                                              158
# Something else                                                                          80
# Professional degree (JD, MD, etc.)                                                      46
# Other doctoral degree (Ph.D., Ed.D., etc.)                                              23
# Associate degree (A.A., A.S., etc.)                                                     21
# Name: EdLevel, dtype: int64

# %%
country_df["CompTotal"].median().loc["India"] #mean salary of Indian Developers
# Out:
# 885000.0

# %%
country_df["CompTotal"].agg(["mean","median"]) #mean and median salary of developers in different countries
# Out:
#                                               mean      median
# Country
# Afghanistan                           3.808414e+06      6000.0
# Albania                               5.104657e+05      5500.0
# Algeria                               8.754444e+04     75000.0
# Andorra                               7.677250e+04     31500.0
# Angola                                1.287990e+09    600000.0
# ...                                            ...         ...
# Venezuela, Bolivarian Republic of...  4.498590e+03      1094.0
# Viet Nam                              4.443807e+07  15000000.0
# Yemen                                 1.071667e+05     20750.0
# Zambia                                5.613333e+03      6200.0
# Zimbabwe                              9.445000e+04       950.0
#
# [180 rows x 2 columns]

# %%
India_filt=df["Country"]=="India"
df.loc[India_filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# 3081

# %%
India_filt=df["Country"]=="India"
df.loc[India_filt]["DevType"].str.contains("Data scientist").sum()
# Out:
# 263

# %%
country_df["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_df["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum()).loc["Canada"] #number of people from canada who work with python
# Out:
# 1272

# %%
country_respondents=df["Country"].value_counts()
country_respondents
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
country_uses_python=country_df["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
python_df=pd.concat([country_respondents,country_uses_python],axis="columns",sort=False)

# %%
python_df
# Out:
#                                                     Country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Seychelles                                                1
# Monaco                                                    1
# Solomon Islands                                           1
# Burkina Faso                                              1
# Djibouti                                                  1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7017
# India                                                                 3081
# ...

# %% [markdown]
# ##### Above table shows the total number of respondents from each country and that how many of them actually work with python

# %%
python_df.rename(columns={"Country":"Number of Respondents","LanguageHaveWorkedWith":"Works with Python"},inplace=True)

# %%
python_df
# Out:
#                                                     Number of Respondents  \
# United States of America                                            13543
# India                                                                6639
# Germany                                                              5395
# United Kingdom of Great Britain and Northern Ir...                   4190
# Canada                                                               2490
# ...                                                                   ...
# Seychelles                                                              1
# Monaco                                                                  1
# Solomon Islands                                                         1
# Burkina Faso                                                            1
# Djibouti                                                                1
#
#                                                     Works with Python
# ...

# %%
python_df["Percentage of Python devs"]=(python_df["Works with Python"]/python_df["Number of Respondents"])*100

# %%
python_df
# Out:
#                                                     Number of Respondents  \
# United States of America                                            13543
# India                                                                6639
# Germany                                                              5395
# United Kingdom of Great Britain and Northern Ir...                   4190
# Canada                                                               2490
# ...                                                                   ...
# Seychelles                                                              1
# Monaco                                                                  1
# Solomon Islands                                                         1
# Burkina Faso                                                            1
# Djibouti                                                                1
#
#                                                     Works with Python  \
# ...

# %%
python_df.loc["India"]  #There are about 46% of python developers from India who entered the survey
# Out:
# Number of Respondents        6639.000000
# Works with Python            3081.000000
# Percentage of Python devs      46.407592
# Name: India, dtype: float64

# %%
python_df.sort_values(by="Percentage of Python devs",ascending=False).head(50)
# Out:
#                                   Number of Respondents  Works with Python  \
# Burkina Faso                                          1                  1
# Solomon Islands                                       1                  1
# Saint Kitts and Nevis                                 1                  1
# Brunei Darussalam                                     1                  1
# Fiji                                                  2                  2
# Papua New Guinea                                      2                  2
# North Korea                                           4                  4
# Lao People's Democratic Republic                      7                  6
# Timor-Leste                                           4                  3
# Suriname                                              4                  3
# Democratic Republic of the Congo                      7                  5
# ...

# %% [markdown]
# ### Cleaning the Data

# %%
import numpy as py

# %%
df.dtypes
# Out:
# ResponseId                          int64
# MainBranch                         object
# Employment                         object
# RemoteWork                         object
# CodingActivities                   object
# EdLevel                            object
# LearnCode                          object
# LearnCodeOnline                    object
# LearnCodeCoursesCert               object
# YearsCode                          object
# YearsCodePro                       object
# DevType                            object
# OrgSize                            object
# PurchaseInfluence                  object
# BuyNewTool                         object
# Country                            object
# Currency                           object
# CompTotal                         float64
# CompFreq                           object
# LanguageHaveWorkedWith             object
# LanguageWantToWorkWith             object
# DatabaseHaveWorkedWith             object
# ...

# %%
df["WorkExp"].head(10)
# Out:
# 6891      2.0
# 38512     NaN
# 43639     NaN
# 43690     8.0
# 2448     15.0
# 6242      3.0
# 23223     7.0
# 49273     NaN
# 55665    14.0
# 3886     30.0
# Name: WorkExp, dtype: float64

# %%
df["WorkExp"].unique()
# Out:
# array([ 2., nan,  8., 15.,  3.,  7., 14., 30.,  5., 13.,  4.,  0.,  1.,
#         6., 18., 50., 12., 17.,  9., 10., 23., 24., 22., 25., 11., 36.,
#        26., 45., 40., 19., 21., 35., 42., 34., 16., 41., 20., 37., 32.,
#        29., 27., 28., 33., 39., 31., 38., 44., 47., 43., 49., 48., 46.])

# %%
df["WorkExp"].dtype
# Out:
# dtype('float64')

# %%
df["WorkExp"].mean()   #10 years of average coding experience for the developers
# Out:
# 10.24237809023906

# %%
df["WorkExp"] = df["WorkExp"].astype(float)
